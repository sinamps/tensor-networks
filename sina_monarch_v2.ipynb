# %% [markdown]
# <a href="https://colab.research.google.com/github/sinamps/tensor-networks/blob/main/sina_monarch_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is version 1. I am going to try the full matrix svd, full matrix svd with permutation, and block-wise svd, and block-wise svd with permutation, and finally monarch code for block-wise svd with permutation.

# %%
# !pip install transformers
# !pip install pytorch_pretrained_bert --upgrade
# !pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytorch_pretrained_bert in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_pretrained_bert) (2.0.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pytorch_pretrained_bert) (1.22.4)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from pytorch_pretrained_bert) (1.26.132)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pytorch_pretrained_bert) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pytorch_pretrained_bert) (4.65.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from pytorch_pretrained_bert) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.1->pytorch_pretrained_bert) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=0.4.1->pytorch_pretrained_bert) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=0.4.1->pytorch_pretrained_bert) (16.0.3)
# Requirement already satisfied: botocore<1.30.0,>=1.29.132 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch_pretrained_bert) (1.29.132)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch_pretrained_bert) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from boto3->pytorch_pretrained_bert) (0.6.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch_pretrained_bert) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch_pretrained_bert) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch_pretrained_bert) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pytorch_pretrained_bert) (3.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.30.0,>=1.29.132->boto3->pytorch_pretrained_bert) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.1->pytorch_pretrained_bert) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.1->pytorch_pretrained_bert) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.132->boto3->pytorch_pretrained_bert) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.6.1)

# %%
from transformers import AutoConfig, AutoTokenizer, BertForPreTraining
# from transformers import cached_path, WEIGHTS_NAME, TF2_WEIGHTS_NAME, TF_WEIGHTS_NAME 
# from transformers.file_utils import is_remote_url, hf_bucket_url
import torch, os, sys
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import locale
locale.getpreferredencoding = lambda: "UTF-8"
from einops import rearrange
import math
from torch.nn import functional as F

# %%
device = torch.device("cuda:0")
model = BertForPreTraining.from_pretrained("bert-large-uncased")
state_dict = model.state_dict()
key_to_load = 'bert.encoder.layer.0.attention.self.query.weight'
fixed_matrix = state_dict[key_to_load].to(device)
fixed_matrix.shape
# Out:
# torch.Size([1024, 1024])

# %%
def reconstruct_from_blocks(blocks):
    
    # blocks is a list of list of blocks
    
    block_size_x = blocks[0][0].shape[0]
    block_size_y = blocks[0][0].shape[1]
    
    x_size = len(blocks)*block_size_x
    y_size = len(blocks[0])*block_size_y
    
    new_matrix = torch.zeros((x_size, y_size))
    
    for i in range(len(blocks)):
        x_index = i*block_size_x
        for j in range(len(blocks[0])):
            y_index = j*block_size_y
            new_matrix[x_index:x_index+block_size_x,y_index:y_index + block_size_y] = blocks[i][j]
    
    return new_matrix


def factors(n):
    return [(i, n // i) for i in range(1, math.floor(math.sqrt(n)) + 1) if n % i == 0]


def low_rank_project(M, rank):
    """Supports batches of matrices as well.
    """
    U, S, Vt = torch.linalg.svd(M)
    S_sqrt = S[..., :rank].sqrt()
    U = U[..., :rank] * rearrange(S_sqrt, '... rank -> ... 1 rank')
    Vt = rearrange(S_sqrt, '... rank -> ... rank 1') * Vt[..., :rank, :]
    return U, Vt


def calculate_all_norms(matrix_1, matrix_2):
    
#     frob = torch.norm(matrix_1.to(matrix_2.device) - matrix_2, p='fro')
    difference_matrix = matrix_1.to(matrix_2.device) - matrix_2
    
    frob = torch.linalg.matrix_norm(difference_matrix, ord='fro')
    
    nuc = torch.linalg.matrix_norm(difference_matrix, ord='nuc')
    
    spectral = torch.linalg.matrix_norm(difference_matrix, ord=2)
    
    norms = {
        'fro': frob,
        'nuc': nuc,
        'spectral': spectral,        
    }
    return norms

# %%
def get_svd(A, r):
  
    """
    Finds the two low-rank matrices of rank r from the matrix A.

    Args:
    A: The input matrix of size m*n.
    r: The rank of the low-rank matrices.

    Returns:
    U: The first low-rank matrix of size m*r.
    V: The second low-rank matrix of size r*n.
    """

    # Get the singular value decomposition of A.
    U, S, V = torch.linalg.svd(A)

    # Keep the first r singular values and their corresponding singular vectors.
    U = U[:, :r]
    S = S[:r]
    V = V[:r, :]

    # Multiply U with S.
    U = U @ S.diag()
    
    reconstructed = torch.matmul(U, V)
#     print(U.shape, V.shape, reconstructed.shape)
    # Return the two low-rank matrices.
    return U, V, reconstructed

# %%
def get_new_svd(A, r):
  
    """
    Finds the two low-rank matrices of rank r from the matrix A.

    Args:
    A: The input matrix of size m*n.
    r: The rank of the low-rank matrices.

    Returns:
    U: The first low-rank matrix of size m*r.
    V: The second low-rank matrix of size r*n.
    """
    '''
    # Get the singular value decomposition of A.
    U, S, V = torch.linalg.svd(A)

    # Keep the first r singular values and their corresponding singular vectors.
    U = U[:, :r]
    S = S[:r]
    V = V[:r, :]

    # Multiply U with S.
    U = U @ S.diag()
    
    U = U.cdouble()
    V = V.cdouble()
    '''
    U, V = low_rank_project(A, rank=r)
    # Vp = rearrange(V, 'k r 1 s -> r k s')
    Vp = rearrange(V, 'i j -> j i')
    # Up = rearrange(U, 'k r s 1 -> k s r')
    Up = rearrange(U, 'i j -> j i')
    reconstructed = torch.matmul(Vp, Up)
#     print(U.shape, V.shape, reconstructed.shape)
    # Return the two low-rank matrices.
    return Vp, Up, reconstructed

# %%
def blockdiag_butterfly_project(M, sizes=None):
    """Only works for square matrices for now
    """
    m, n = M.shape
    if m != n:
        raise NotImplementedError('Only support square matrices')
    if sizes is None:
        # Find the factors that are closest to sqrt(n)
        sizes = factors(n)[-1]
        # Larger factor first is probably more efficient, idk
        sizes = (sizes[1], sizes[0])
    assert n == sizes[0] * sizes[1]
    M_permuted_batched = rearrange(M, '(p k) (r s) -> k r p s', k=sizes[1], r=sizes[0])
    U, Vt = low_rank_project(M_permuted_batched, rank=1)
    w1_bfly = rearrange(Vt, 'k r 1 s -> r k s')
    w2_bfly = rearrange(U, 'k r s 1 -> k s r')
    return w1_bfly, w2_bfly

# %%
class BlockdiagButterflyMultiply(torch.autograd.Function):

    """This is a faster implementation, with careful memory copies for the fastest
    bmm performance.
    The backward pass is also written manually with careful memory copies.
    Arguments:
        x: (batch, n)
        w1_bfly: (k, q, p), where k = n / p
        w2_bfly: (l, s, r), where l = k * q / r = n * q / (p * r)
    Outputs:
        out: (batch, m), where m = l * s = n * s * q / (p * r)
    """

    @staticmethod
    @torch.cuda.amp.custom_fwd(cast_inputs=torch.float16)
    def forward(ctx, x, w1_bfly, w2_bfly):
        batch_shape, n = x.shape[:-1], x.shape[-1]
        batch_dim = np.prod(batch_shape)
        k, q, p = w1_bfly.shape
        l, s, r = w2_bfly.shape
        assert k * p == n
        assert l * r == k * q
        x_reshaped = x.reshape(batch_dim, k, p).transpose(0, 1)
        out1 = torch.empty(batch_dim, k, q, device=x.device, dtype=x.dtype).transpose(0, 1)
        out1 = torch.bmm(x_reshaped, w1_bfly.transpose(-1, -2), out=out1)
        out1 = out1.transpose(0, 1).reshape(batch_dim, r, l).transpose(-1, -2).contiguous().transpose(0, 1)
        out2 = torch.empty(batch_dim, l, s, device=x.device, dtype=x.dtype).transpose(0, 1)
        out2 = torch.bmm(out1, w2_bfly.transpose(-1, -2), out=out2)
        out2 = out2.permute(1, 2, 0).reshape(*batch_shape, s * l)
        ctx.save_for_backward(x, w1_bfly, w2_bfly, out1)
        return out2

    @staticmethod
    @torch.cuda.amp.custom_bwd
    def backward(ctx, dout):
        x, w1_bfly, w2_bfly, out1 = ctx.saved_tensors
        batch_shape, n = x.shape[:-1], x.shape[-1]
        batch_dim = np.prod(batch_shape)
        k, q, p = w1_bfly.shape
        l, s, r = w2_bfly.shape
        # assert k * p == n
        # assert l * r == k * q
        dx, dw1_bfly, dw2_bfly = None, None, None
        # dout_reshaped = dout.reshape(batch_dim, sqrtn, sqrtn).permute(2, 1, 0).contiguous()
        dout_reshaped = dout.reshape(batch_dim, s, l).transpose(-1, -2).contiguous()
        dout_reshaped = dout_reshaped.transpose(0, 1)
        if ctx.needs_input_grad[2]:
            # dw2_bfly = torch.empty(l, s, r, device=w2_bfly.device, dtype=w2_bfly.dtype)
            # dw2_bfly = torch.bmm(dout_reshaped.transpose(-1, -2), out1, out=dw2_bfly)
            dw2_bfly = torch.bmm(dout_reshaped.transpose(-1, -2), out1.conj())
        if ctx.needs_input_grad[1] or ctx.needs_input_grad[0]:
            dout1 = torch.empty(batch_dim, l, r, device=x.device, dtype=x.dtype).transpose(0, 1)
            dout1 = torch.bmm(dout_reshaped, w2_bfly.conj(), out=dout1)
            dout1 = dout1.transpose(0, 1).transpose(-1, -2).contiguous().reshape(batch_dim, k, q).transpose(0, 1)
            # dout1 = dout1.permute(1, 2, 0).contiguous().transpose(0, 1)
            if ctx.needs_input_grad[0]:
                dx = torch.empty(batch_dim, k, p, device=x.device, dtype=x.dtype)
                dx = torch.bmm(dout1, w1_bfly.conj(), out=dx.transpose(0, 1)).transpose(0, 1).reshape(*batch_shape, n)
            if ctx.needs_input_grad[1]:
                x_reshaped = x.reshape(batch_dim, k, p).transpose(0, 1)
                dw1_bfly = torch.bmm(dout1.transpose(-1, -2), x_reshaped.conj())
        return dx, dw1_bfly, dw2_bfly

blockdiag_butterfly_multiply = BlockdiagButterflyMultiply.apply

# %% [markdown]
# This is the code based on monarch's code to get L and R from monarch decomposition.

# %%
def get_monarch(fixed_matrix):
    # set seed
    # torch.random.manual_seed(0)
    n = fixed_matrix.shape[1]
    log_n = torch.log2(torch.tensor(n))
    # n = 1 << log_n
    log_n = int(log_n)
    sqrtn = 1 << (log_n // 2)
    batch_size = 1
    eye = torch.eye(n, device=device)
    # myweights = fixed_matrix.cfloat()
    # transform = torch.fft.fft if direction == 'fft' else torch.fft.ifft
    # dft = transform(eye, norm='ortho').t()
    # dft = transform(myweights, norm='ortho').t()
    # perm = bitreversal_permutation(n)
    # We don't actually need the bitreversal permutation, any permutation that swap
    # the axes of the sqrtn x sqrtn input will work.
    perm = rearrange(torch.arange(n, device=device), '(i j) -> (j i)', i=sqrtn)
    # The BP (butterfly - permutation) decomposition of FFT / iFFT
    # Converting to complex128 makes the approximation an order of magnitude more accurate
    w1_fft_projected, w2_fft_projected = blockdiag_butterfly_project(fixed_matrix[:, perm])
    # w1_fft_projected, w2_fft_projected = w1_fft_projected.cfloat(), w2_fft_projected.cfloat()
    recons = blockdiag_butterfly_multiply(eye, w1_fft_projected, w2_fft_projected)
    # recons = torch.matmul(w1_fft_projected, w2_fft_projected).cfloat()
    # fft_projected = blockdiag_butterfly_multiply(myweights, w1_fft_projected, w2_fft_projected).t()
    # fft_projected = blockdiag_butterfly_multiply(myinput, w1_fft_projected, w2_fft_projected)
    # fft_projected = torch.matmul(myweights_t, w1_fft_projected)
    # fft_projected = torch.matmul(fft_projected, w2_fft_projected).t()
    # print("shapes")
    # print(fft_projected.shape)
    # print(myinput.shape)
    # print(myinput[:, perm].shape)
    # print("max abs difference:", (fft_projected - myinput[:, perm]).abs().max())
    # assert torch.allclose(fft_projected, dft[:, perm], rtol=1e-4, atol=1e-4)
    # print(torch.norm(fft_projected - myinput[:, perm], p='fro'))
    # return fft_projected
    # x = torch.randn(batch_size, n, dtype=torch.complex64, device=
    return w1_fft_projected, w2_fft_projected, recons

# %%
def split_and_run_svd(fixed_matrix, block_size_x, block_size_y, rank, decomp):
    
    # Should return the full reconstructed matrix along with the block-wise low-rank decompositions
    # x for rows, y for columns
    # assuming that each index is perfectly divisible by the block sizes
    
    n_blocks_x = int(fixed_matrix.shape[0]/block_size_x)
    n_blocks_y = int(fixed_matrix.shape[1]/block_size_y)
    
    print(f'Num Blocks in x (rows): {n_blocks_x}')
    print(f'Num Blocks in y (cols): {n_blocks_y}')
    
    num_params = np.prod([n_blocks_x, n_blocks_y, (block_size_x+block_size_y)*rank])

    print('Num parameters in the resulting decomposition ', num_params)
    print('Num parameters in the original matrix ', fixed_matrix.shape[0]*fixed_matrix.shape[1])
    
    
    # partition original matrix into blocks
    
    fixed_matrix_blocks = list()
    # lmf_blocks = list()
    for i in range(n_blocks_x):
        x_index = i*block_size_x
        column_block_list = []
        for j in range(n_blocks_y):
            y_index = j*block_size_y
            block = fixed_matrix[x_index:x_index+block_size_x, y_index:y_index + block_size_y]
            column_block_list.append(block)
        fixed_matrix_blocks.append(column_block_list)
    
    low_ranks = list()
    low_ranks_blocks = list() # reconstructed blocks from low-rank decompositions
    
    for i in range(len(fixed_matrix_blocks)):
        low_ranks_cols = list()
        low_ranks_cols_blocks = list()
        
        for j in range(len(fixed_matrix_blocks[0])):
            if decomp == 'svd':
              left, right, reconstructed = get_svd(fixed_matrix_blocks[i][j], rank)
            elif decomp == 'svd_p':
              left, right, reconstructed = get_new_svd(fixed_matrix_blocks[i][j], rank)
            elif decomp == 'monarch':
              left, right, reconstructed = get_monarch(fixed_matrix_blocks[i][j])
            else:
              raise Exception("No decomposition is specified!")
                
            # left, right, reconstructed = get_monarch(fixed_matrix_blocks[i][j])

#             left, right, reconstructed = get_sgd(fixed_matrix_blocks[i][j], rank)
#             print(left.shape, right.shape, reconstructed.shape)
            low_ranks_cols.append((left, right))
            low_ranks_cols_blocks.append(reconstructed)
#         print(f'{i+1}/{len(fixed_matrix_blocks)} done')
        
        low_ranks.append(low_ranks_cols)
        low_ranks_blocks.append(low_ranks_cols_blocks)
    return low_ranks, low_ranks_blocks, fixed_matrix_blocks, num_params

# %%
def find_closest_rank_full_matrix_decomposition(fixed_matrix, desired_num_params):
    
    rank = int(desired_num_params / (fixed_matrix.shape[0] + fixed_matrix.shape[1]))
    num_p = (fixed_matrix.shape[0] + fixed_matrix.shape[1])*rank
    
    print(f'Rank that gives parameters closest to {desired_num_params} is rank:{rank} with params: {num_p}')
    
    left, right, reconstructed = get_svd(fixed_matrix, rank)
    
    return left, right, reconstructed

# %%
svd_low_ranks, svd_low_ranks_blocks, svd_fixed_matrix_blocks, svd_num_params_block_svd = split_and_run_svd(fixed_matrix, block_size_x=32, block_size_y=32, rank=1, decomp='svd')
ma_low_ranks, ma_low_ranks_blocks, ma_fixed_matrix_blocks, ma_num_params_block_svd = split_and_run_svd(fixed_matrix, block_size_x=32, block_size_y=32, rank=1, decomp='monarch')
# Out:
# Num Blocks in x (rows): 32
# Num Blocks in y (cols): 32
# Num parameters in the resulting decomposition  65536
# Num parameters in the original matrix  1048576
# Num Blocks in x (rows): 32
# Num Blocks in y (cols): 32
# Num parameters in the resulting decomposition  65536
# Num parameters in the original matrix  1048576

# %%
perm = rearrange(torch.arange(1024, device=device), '(i j) -> (j i)', i=32)

reconstructed_matrix_svd = reconstruct_from_blocks(svd_fixed_matrix_blocks)
reconstructed_matrix_ma = reconstruct_from_blocks(svd_fixed_matrix_blocks)
print("diff: reconstructed from blocks vs. original:")
print(torch.norm(reconstructed_matrix_svd.to(fixed_matrix.device) - fixed_matrix, p='fro'))
assert torch.norm(reconstructed_matrix_svd.to(device) - reconstructed_matrix_ma.to(device), p='fro') == torch.tensor(0)
print("\n")
reconstructed_block_svd = reconstruct_from_blocks(svd_low_ranks_blocks)
print("diff: reconstructed from low-rank svd blocks vs. original:")
print(torch.norm(reconstructed_block_svd.to(fixed_matrix.device) - fixed_matrix, p='fro'))
print("\n")
reconstructed_block_monarch = reconstruct_from_blocks(ma_low_ranks_blocks)
print("diff: reconstructed from low-rank monarch blocks vs. original:")
print(torch.norm(reconstructed_block_monarch.to(fixed_matrix.device) - fixed_matrix[:, perm], p='fro'))
print("\n")
_, _, reconstructed_svd_full_matched_rank = find_closest_rank_full_matrix_decomposition(fixed_matrix, svd_num_params_block_svd)
print("diff: reconstructed from full matrix svd with matching rank vs. original:")
print(torch.norm(reconstructed_svd_full_matched_rank.to(fixed_matrix.device) - fixed_matrix, p='fro'))
print("\n")
_, _, reconstructed_svd_full = get_svd(fixed_matrix, 1)
print("diff: reconstructed from full matrix svd with rank 1 vs. original:")
print(torch.norm(reconstructed_svd_full.to(fixed_matrix.device) - fixed_matrix, p='fro'))
print("\n")
_, _, reconstructed_monarch_full = get_monarch(fixed_matrix)
print("diff: reconstructed from full matrix monarch vs. original:")
print(torch.norm(reconstructed_monarch_full.to(fixed_matrix.device) - fixed_matrix[:, perm], p='fro'))
# Out:
# diff: reconstructed from blocks vs. original:
# tensor(0., device='cuda:0')
#
#
# diff: reconstructed from low-rank svd blocks vs. original:
# tensor(33.2463, device='cuda:0')
#
#
# diff: reconstructed from low-rank monarch blocks vs. original:
# tensor(44.6162, device='cuda:0')
#
#
# Rank that gives parameters closest to 65536 is rank:32 with params: 65536
# diff: reconstructed from full matrix svd with matching rank vs. original:
# tensor(31.0410, device='cuda:0')
#
#
# diff: reconstructed from full matrix svd with rank 1 vs. original:
# tensor(35.6478, device='cuda:0')
#
#
# diff: reconstructed from full matrix monarch vs. original:
# tensor(38.3040, device='cuda:0')

# %%
print(calculate_all_norms(fixed_matrix, reconstructed_monarch_full))
print(calculate_all_norms(fixed_matrix, reconstructed_block_monarch))
print(calculate_all_norms(fixed_matrix, reconstructed_svd_full_matched_rank))
print(calculate_all_norms(fixed_matrix, reconstructed_block_svd))
# Out:
# {'fro': tensor(38.3195, device='cuda:0'), 'nuc': tensor(955.1649, device='cuda:0'), 'spectral': tensor(5.2226, device='cuda:0')}
# {'fro': tensor(44.5996), 'nuc': tensor(1155.3595), 'spectral': tensor(5.3252)}
# {'fro': tensor(31.0410, device='cuda:0'), 'nuc': tensor(785.1836, device='cuda:0'), 'spectral': tensor(2.3623, device='cuda:0')}
# {'fro': tensor(33.2460), 'nuc': tensor(845.9597), 'spectral': tensor(3.5511)}

# %%
# torch.manual_seed(0)
better = list()
counter = 0
for i in range(500):
  myinput = torch.rand(16, 1024).to(device)
  # assert torch.allclose(myrecons, fixed_matrix[:, perm].cfloat(), rtol=1e-4, atol=1e-4)
  true_res = torch.matmul(myinput, fixed_matrix.t())

  #_, _, recons_fullsvd = get_svd(fixed_matrix, 1)
  #full_svd_res = torch.matmul(myinput, recons_fullsvd)
  #print(torch.norm(full_svd_res - true_res, p='fro'))

  # L, R, ma_recons = get_monarch(fixed_matrix)
  # monarch_res = blockdiag_butterfly_multiply(myinput[:, perm], L, R)
  # monarch_res_2 = torch.matmul(myinput[:, perm], ma_recons)
  # print(torch.norm(monarch_res - true_res, p='fro'))
  # mon = torch.norm(monarch_res_2 - true_res, p='fro')



  # print("\n")
  # ysvd = torch.matmul(myinput, reconstructed_svd_full)
  # print(torch.norm(ysvd - true_res, p='fro'))
  ysvd_matchedrank = torch.matmul(myinput, reconstructed_svd_full_matched_rank)
  svd = torch.norm(ysvd_matchedrank - true_res, p='fro')
  print(svd)
  
  ymonarch = torch.matmul(myinput, reconstructed_monarch_full)
  mon = torch.norm(ymonarch - true_res, p='fro')
  print(mon)
  # print("\n")
  # yblocksvd = torch.matmul(myinput, reconstructed_block_svd.to(device))
  # print(torch.norm(yblocksvd - true_res, p='fro'))
  # yblockmonarch = torch.matmul(myinput, reconstructed_block_monarch.to(device))
  # print(torch.norm(yblockmonarch - true_res, p='fro'))
  print("\n")
  if mon <= svd:
    counter = counter + 1

print(counter)
# Out:
# tensor(88.2836, device='cuda:0')
# tensor(77.7914, device='cuda:0')
#
#
# tensor(89.7439, device='cuda:0')
# tensor(78.8039, device='cuda:0')
#
#
# tensor(87.7617, device='cuda:0')
# tensor(78.3627, device='cuda:0')
#
#
# tensor(87.4255, device='cuda:0')
# tensor(76.7803, device='cuda:0')
#
#
# tensor(89.0154, device='cuda:0')
# tensor(78.4655, device='cuda:0')
#
#
# tensor(89.1359, device='cuda:0')
# tensor(78.8584, device='cuda:0')
#
#
# tensor(87.0653, device='cuda:0')
# tensor(77.8473, device='cuda:0')
#
#
# tensor(88.8364, device='cuda:0')
# tensor(78.2332, device='cuda:0')
#
#
# tensor(87.1475, device='cuda:0')
# tensor(76.7762, device='cuda:0')
#
#
# tensor(87.7558, device='cuda:0')
# tensor(78.1693, device='cuda:0')
#
#
# tensor(87.5617, device='cuda:0')
# tensor(77.9478, device='cuda:0')
#
#
# tensor(88.4784, device='cuda:0')
# tensor(77.9631, device='cuda:0')
#
#
# tensor(87.6916, device='cuda:0')
# tensor(77.7030, device='cuda:0')
#
#
# tensor(88.6739, device='cuda:0')
# tensor(79.1525, device='cuda:0')
#
#
# tensor(88.1446, device='cuda:0')
# tensor(77.4345, device='cuda:0')
#
#
# tensor(87.9976, device='cuda:0')
# tensor(77.6813, device='cuda:0')
#
#
# tensor(89.3088, device='cuda:0')
# tensor(78.5902, device='cuda:0')
#
#
# tensor(88.5953, device='cuda:0')
# tensor(77.8845, device='cuda:0')
#
#
# tensor(87.9449, device='cuda:0')
# tensor(78.0615, device='cuda:0')
#
#
# tensor(87.9840, device='cuda:0')
# tensor(78.0763, device='cuda:0')
#
#
# tensor(87.5874, device='cuda:0')
# tensor(77.4281, device='cuda:0')
#
#
# tensor(87.7843, device='cuda:0')
# tensor(77.7891, device='cuda:0')
#
#
# tensor(88.6600, device='cuda:0')
# tensor(78.3420, device='cuda:0')
#
#
# tensor(88.2348, device='cuda:0')
# tensor(78.2733, device='cuda:0')
#
#
# tensor(88.6707, device='cuda:0')
# tensor(78.4478, device='cuda:0')
#
#
# tensor(87.3596, device='cuda:0')
# tensor(77.6152, device='cuda:0')
#
#
# tensor(89.5436, device='cuda:0')
# tensor(79.7098, device='cuda:0')
#
#
# tensor(87.8686, device='cuda:0')
# tensor(77.7068, device='cuda:0')
#
#
# tensor(89.1264, device='cuda:0')
# tensor(78.3734, device='cuda:0')
#
#
# tensor(88.1117, device='cuda:0')
# tensor(78.3112, device='cuda:0')
#
#
# tensor(87.3775, device='cuda:0')
# tensor(77.4705, device='cuda:0')
#
#
# tensor(89.8154, device='cuda:0')
# tensor(79.5689, device='cuda:0')
#
#
# tensor(87.3917, device='cuda:0')
# tensor(77.0277, device='cuda:0')
#
#
# tensor(87.9138, device='cuda:0')
# tensor(77.9033, device='cuda:0')
#
#
# tensor(89.5700, device='cuda:0')
# tensor(79.0304, device='cuda:0')
#
#
# tensor(89.1156, device='cuda:0')
# tensor(78.9237, device='cuda:0')
#
#
# tensor(88.6221, device='cuda:0')
# tensor(79.1736, device='cuda:0')
#
#
# tensor(88.6997, device='cuda:0')
# tensor(77.7950, device='cuda:0')
#
#
# tensor(88.5540, device='cuda:0')
# tensor(78.5617, device='cuda:0')
#
#
# tensor(88.3237, device='cuda:0')
# tensor(78.8040, device='cuda:0')
#
#
# tensor(87.8379, device='cuda:0')
# tensor(77.6618, device='cuda:0')
#
#
# tensor(87.8949, device='cuda:0')
# tensor(77.7937, device='cuda:0')
#
#
# tensor(89.3321, device='cuda:0')
# tensor(78.0599, device='cuda:0')
#
#
# tensor(89.3927, device='cuda:0')
# tensor(79.2476, device='cuda:0')
#
#
# tensor(88.1788, device='cuda:0')
# tensor(78.6623, device='cuda:0')
#
#
# tensor(87.8552, device='cuda:0')
# tensor(77.8686, device='cuda:0')
#
#
# tensor(86.8020, device='cuda:0')
# tensor(76.6127, device='cuda:0')
#
#
# tensor(88.3157, device='cuda:0')
# tensor(77.6929, device='cuda:0')
#
#
# tensor(87.5963, device='cuda:0')
# tensor(77.8830, device='cuda:0')
#
#
# tensor(87.5595, device='cuda:0')
# tensor(77.7341, device='cuda:0')
#
#
# tensor(88.1988, device='cuda:0')
# tensor(77.9474, device='cuda:0')
#
#
# tensor(88.0356, device='cuda:0')
# tensor(78.2833, device='cuda:0')
#
#
# tensor(86.3685, device='cuda:0')
# tensor(76.2040, device='cuda:0')
#
#
# tensor(88.0624, device='cuda:0')
# tensor(78.2031, device='cuda:0')
#
#
# tensor(87.9073, device='cuda:0')
# tensor(78.3519, device='cuda:0')
#
#
# tensor(86.9090, device='cuda:0')
# tensor(77.1391, device='cuda:0')
#
#
# tensor(88.8054, device='cuda:0')
# tensor(79.4644, device='cuda:0')
#
#
# tensor(88.6584, device='cuda:0')
# tensor(78.7891, device='cuda:0')
#
#
# tensor(88.2158, device='cuda:0')
# tensor(77.7805, device='cuda:0')
#
#
# tensor(88.4799, device='cuda:0')
# tensor(78.2031, device='cuda:0')
#
#
# tensor(87.7592, device='cuda:0')
# tensor(77.6685, device='cuda:0')
#
#
# tensor(88.4551, device='cuda:0')
# tensor(78.3871, device='cuda:0')
#
#
# tensor(87.7174, device='cuda:0')
# tensor(78.0078, device='cuda:0')
#
#
# tensor(89.0183, device='cuda:0')
# tensor(79.7053, device='cuda:0')
#
#
# tensor(87.0634, device='cuda:0')
# tensor(76.8669, device='cuda:0')
#
#
# tensor(87.7090, device='cuda:0')
# tensor(77.2539, device='cuda:0')
#
#
# tensor(87.8148, device='cuda:0')
# tensor(77.1191, device='cuda:0')
#
#
# tensor(86.9217, device='cuda:0')
# tensor(77.0142, device='cuda:0')
#
#
# tensor(88.3521, device='cuda:0')
# tensor(77.6036, device='cuda:0')
#
#
# tensor(87.3893, device='cuda:0')
# tensor(77.5902, device='cuda:0')
#
#
# tensor(88.0163, device='cuda:0')
# tensor(77.2201, device='cuda:0')
#
#
# tensor(87.9072, device='cuda:0')
# tensor(77.1002, device='cuda:0')
#
#
# tensor(88.7514, device='cuda:0')
# tensor(78.9569, device='cuda:0')
#
#
# tensor(88.4449, device='cuda:0')
# tensor(78.3067, device='cuda:0')
#
#
# tensor(89.0798, device='cuda:0')
# tensor(78.0642, device='cuda:0')
#
#
# tensor(87.7979, device='cuda:0')
# tensor(77.4488, device='cuda:0')
#
#
# tensor(89.2337, device='cuda:0')
# tensor(78.5562, device='cuda:0')
#
#
# tensor(87.2018, device='cuda:0')
# tensor(77.3911, device='cuda:0')
#
#
# tensor(87.9473, device='cuda:0')
# tensor(77.8497, device='cuda:0')
#
#
# tensor(87.8018, device='cuda:0')
# tensor(78.3024, device='cuda:0')
#
#
# tensor(88.6934, device='cuda:0')
# tensor(77.2192, device='cuda:0')
#
#
# tensor(88.9568, device='cuda:0')
# tensor(78.9324, device='cuda:0')
#
#
# tensor(88.1270, device='cuda:0')
# tensor(78.2710, device='cuda:0')
#
#
# tensor(88.8349, device='cuda:0')
# tensor(77.5173, device='cuda:0')
#
#
# tensor(87.9315, device='cuda:0')
# tensor(78.1020, device='cuda:0')
#
#
# tensor(88.1613, device='cuda:0')
# tensor(78.1013, device='cuda:0')
#
#
# tensor(88.1720, device='cuda:0')
# tensor(78.0815, device='cuda:0')
#
#
# tensor(88.7249, device='cuda:0')
# tensor(78.0323, device='cuda:0')
#
#
# tensor(89.1807, device='cuda:0')
# tensor(79.3655, device='cuda:0')
#
#
# tensor(88.5329, device='cuda:0')
# tensor(77.5283, device='cuda:0')
#
#
# tensor(88.8026, device='cuda:0')
# tensor(79.8625, device='cuda:0')
#
#
# tensor(87.9758, device='cuda:0')
# tensor(77.5373, device='cuda:0')
#
#
# tensor(89.4160, device='cuda:0')
# tensor(78.7484, device='cuda:0')
#
#
# tensor(88.2681, device='cuda:0')
# tensor(77.5487, device='cuda:0')
#
#
# tensor(87.1911, device='cuda:0')
# tensor(76.8484, device='cuda:0')
#
#
# tensor(88.0045, device='cuda:0')
# tensor(77.7667, device='cuda:0')
#
#
# tensor(88.2467, device='cuda:0')
# tensor(77.0422, device='cuda:0')
#
#
# tensor(88.1027, device='cuda:0')
# tensor(77.7738, device='cuda:0')
#
#
# tensor(86.6526, device='cuda:0')
# tensor(76.9157, device='cuda:0')
#
#
# tensor(87.8106, device='cuda:0')
# tensor(78.5815, device='cuda:0')
#
#
# tensor(88.3996, device='cuda:0')
# tensor(78.0588, device='cuda:0')
#
#
# tensor(89.0512, device='cuda:0')
# tensor(78.6622, device='cuda:0')
#
#
# tensor(88.4676, device='cuda:0')
# tensor(78.5482, device='cuda:0')
#
#
# tensor(88.3897, device='cuda:0')
# tensor(78.2169, device='cuda:0')
#
#
# tensor(87.6407, device='cuda:0')
# tensor(78.6363, device='cuda:0')
#
#
# tensor(88.7872, device='cuda:0')
# tensor(77.5446, device='cuda:0')
#
#
# tensor(88.3158, device='cuda:0')
# tensor(77.8471, device='cuda:0')
#
#
# tensor(89.5548, device='cuda:0')
# tensor(80.1059, device='cuda:0')
#
#
# tensor(88.0905, device='cuda:0')
# tensor(77.8919, device='cuda:0')
#
#
# tensor(87.2120, device='cuda:0')
# tensor(77.2060, device='cuda:0')
#
#
# tensor(88.3924, device='cuda:0')
# tensor(78.4091, device='cuda:0')
#
#
# tensor(88.8395, device='cuda:0')
# tensor(77.3568, device='cuda:0')
#
#
# tensor(89.1376, device='cuda:0')
# tensor(79.0147, device='cuda:0')
#
#
# tensor(88.4652, device='cuda:0')
# tensor(78.3655, device='cuda:0')
#
#
# tensor(87.7801, device='cuda:0')
# tensor(77.1289, device='cuda:0')
#
#
# tensor(87.9029, device='cuda:0')
# tensor(78.3304, device='cuda:0')
#
#
# tensor(88.2553, device='cuda:0')
# tensor(78.4327, device='cuda:0')
#
#
# tensor(87.9789, device='cuda:0')
# tensor(77.7977, device='cuda:0')
#
#
# tensor(88.4039, device='cuda:0')
# tensor(78.2328, device='cuda:0')
#
#
# tensor(88.5034, device='cuda:0')
# tensor(77.8590, device='cuda:0')
#
#
# tensor(88.0446, device='cuda:0')
# tensor(77.6450, device='cuda:0')
#
#
# tensor(87.9254, device='cuda:0')
# tensor(77.7268, device='cuda:0')
#
#
# tensor(88.4928, device='cuda:0')
# tensor(77.6334, device='cuda:0')
#
#
# tensor(87.0134, device='cuda:0')
# tensor(77.1940, device='cuda:0')
#
#
# tensor(87.7076, device='cuda:0')
# tensor(76.6372, device='cuda:0')
#
#
# tensor(87.6398, device='cuda:0')
# tensor(77.5027, device='cuda:0')
#
#
# tensor(87.0380, device='cuda:0')
# tensor(76.8596, device='cuda:0')
#
#
# tensor(86.7880, device='cuda:0')
# tensor(77.0449, device='cuda:0')
#
#
# tensor(88.2153, device='cuda:0')
# tensor(78.1462, device='cuda:0')
#
#
# tensor(86.4896, device='cuda:0')
# tensor(76.1770, device='cuda:0')
#
#
# tensor(87.4416, device='cuda:0')
# tensor(77.7464, device='cuda:0')
#
#
# tensor(88.6802, device='cuda:0')
# tensor(78.0368, device='cuda:0')
#
#
# tensor(86.7666, device='cuda:0')
# tensor(77.3843, device='cuda:0')
#
#
# tensor(87.8498, device='cuda:0')
# tensor(77.7248, device='cuda:0')
#
#
# tensor(89.9468, device='cuda:0')
# tensor(79.2054, device='cuda:0')
#
#
# tensor(88.6878, device='cuda:0')
# tensor(78.1734, device='cuda:0')
#
#
# tensor(87.8129, device='cuda:0')
# tensor(78.2804, device='cuda:0')
#
#
# tensor(87.7927, device='cuda:0')
# tensor(78.2898, device='cuda:0')
#
#
# tensor(86.8556, device='cuda:0')
# tensor(77.2139, device='cuda:0')
#
#
# tensor(88.0241, device='cuda:0')
# tensor(78.4643, device='cuda:0')
#
#
# tensor(89.3095, device='cuda:0')
# tensor(78.4692, device='cuda:0')
#
#
# tensor(87.1991, device='cuda:0')
# tensor(77.0389, device='cuda:0')
#
#
# tensor(89.1284, device='cuda:0')
# tensor(78.9619, device='cuda:0')
#
#
# tensor(88.8727, device='cuda:0')
# tensor(78.2231, device='cuda:0')
#
#
# tensor(88.0602, device='cuda:0')
# tensor(77.2142, device='cuda:0')
#
#
# tensor(88.6509, device='cuda:0')
# tensor(78.4219, device='cuda:0')
#
#
# tensor(86.9489, device='cuda:0')
# tensor(76.1947, device='cuda:0')
#
#
# tensor(89.5560, device='cuda:0')
# tensor(79.3711, device='cuda:0')
#
#
# tensor(88.9382, device='cuda:0')
# tensor(79.2183, device='cuda:0')
#
#
# tensor(87.9247, device='cuda:0')
# tensor(78.2531, device='cuda:0')
#
#
# tensor(89.2803, device='cuda:0')
# tensor(78.9597, device='cuda:0')
#
#
# tensor(88.3760, device='cuda:0')
# tensor(77.4158, device='cuda:0')
#
#
# tensor(88.2233, device='cuda:0')
# tensor(77.9592, device='cuda:0')
#
#
# tensor(87.5913, device='cuda:0')
# tensor(78.3013, device='cuda:0')
#
#
# tensor(88.0259, device='cuda:0')
# tensor(77.7071, device='cuda:0')
#
#
# tensor(88.8652, device='cuda:0')
# tensor(77.9127, device='cuda:0')
#
#
# tensor(87.8944, device='cuda:0')
# tensor(77.8873, device='cuda:0')
#
#
# tensor(86.9564, device='cuda:0')
# tensor(76.6656, device='cuda:0')
#
#
# tensor(87.5980, device='cuda:0')
# tensor(77.1353, device='cuda:0')
#
#
# tensor(87.8825, device='cuda:0')
# tensor(77.1013, device='cuda:0')
#
#
# tensor(88.4537, device='cuda:0')
# tensor(77.5928, device='cuda:0')
#
#
# tensor(88.0144, device='cuda:0')
# tensor(77.7114, device='cuda:0')
#
#
# tensor(86.8091, device='cuda:0')
# tensor(77.4215, device='cuda:0')
#
#
# tensor(89.0827, device='cuda:0')
# tensor(79.2568, device='cuda:0')
#
#
# tensor(88.0816, device='cuda:0')
# tensor(78.0429, device='cuda:0')
#
#
# tensor(87.1868, device='cuda:0')
# tensor(77.4143, device='cuda:0')
#
#
# tensor(88.0873, device='cuda:0')
# tensor(77.5552, device='cuda:0')
#
#
# tensor(88.5286, device='cuda:0')
# tensor(78.3622, device='cuda:0')
#
#
# tensor(88.1631, device='cuda:0')
# tensor(79.1343, device='cuda:0')
#
#
# tensor(87.3726, device='cuda:0')
# tensor(75.8360, device='cuda:0')
#
#
# tensor(87.2394, device='cuda:0')
# tensor(77.6023, device='cuda:0')
#
#
# tensor(87.4691, device='cuda:0')
# tensor(77.7151, device='cuda:0')
#
#
# tensor(86.7095, device='cuda:0')
# tensor(76.2096, device='cuda:0')
#
#
# tensor(87.6127, device='cuda:0')
# tensor(77.6712, device='cuda:0')
#
#
# tensor(88.1227, device='cuda:0')
# tensor(78.0959, device='cuda:0')
#
#
# tensor(88.8695, device='cuda:0')
# tensor(78.3815, device='cuda:0')
#
#
# tensor(88.2191, device='cuda:0')
# tensor(76.9131, device='cuda:0')
#
#
# tensor(88.2232, device='cuda:0')
# tensor(78.4582, device='cuda:0')
#
#
# tensor(89.3979, device='cuda:0')
# tensor(77.9345, device='cuda:0')
#
#
# tensor(88.4737, device='cuda:0')
# tensor(77.7329, device='cuda:0')
#
#
# tensor(87.8893, device='cuda:0')
# tensor(78.0508, device='cuda:0')
#
#
# tensor(88.0976, device='cuda:0')
# tensor(78.2462, device='cuda:0')
#
#
# tensor(87.5606, device='cuda:0')
# tensor(77.3566, device='cuda:0')
#
#
# tensor(87.8549, device='cuda:0')
# tensor(78.1624, device='cuda:0')
#
#
# tensor(88.3712, device='cuda:0')
# tensor(78.1500, device='cuda:0')
#
#
# tensor(87.0533, device='cuda:0')
# tensor(76.7078, device='cuda:0')
#
#
# tensor(87.7151, device='cuda:0')
# tensor(77.6279, device='cuda:0')
#
#
# tensor(87.4240, device='cuda:0')
# tensor(77.2100, device='cuda:0')
#
#
# tensor(87.5688, device='cuda:0')
# tensor(77.6623, device='cuda:0')
#
#
# tensor(89.3592, device='cuda:0')
# tensor(78.6899, device='cuda:0')
#
#
# tensor(87.9625, device='cuda:0')
# tensor(77.8473, device='cuda:0')
#
#
# tensor(89.6767, device='cuda:0')
# tensor(78.3636, device='cuda:0')
#
#
# tensor(88.0506, device='cuda:0')
# tensor(77.9705, device='cuda:0')
#
#
# tensor(88.5127, device='cuda:0')
# tensor(76.8196, device='cuda:0')
#
#
# tensor(88.3680, device='cuda:0')
# tensor(78.1234, device='cuda:0')
#
#
# tensor(87.6130, device='cuda:0')
# tensor(77.8302, device='cuda:0')
#
#
# tensor(87.5942, device='cuda:0')
# tensor(78.4466, device='cuda:0')
#
#
# tensor(88.6184, device='cuda:0')
# tensor(77.6664, device='cuda:0')
#
#
# tensor(86.9357, device='cuda:0')
# tensor(76.8070, device='cuda:0')
#
#
# tensor(87.9644, device='cuda:0')
# tensor(78.3330, device='cuda:0')
#
#
# tensor(88.8554, device='cuda:0')
# tensor(78.3264, device='cuda:0')
#
#
# tensor(87.4431, device='cuda:0')
# tensor(76.7020, device='cuda:0')
#
#
# tensor(88.8824, device='cuda:0')
# tensor(78.5599, device='cuda:0')
#
#
# tensor(87.4341, device='cuda:0')
# tensor(77.9407, device='cuda:0')
#
#
# tensor(87.3632, device='cuda:0')
# tensor(77.2247, device='cuda:0')
#
#
# tensor(89.1667, device='cuda:0')
# tensor(79.7056, device='cuda:0')
#
#
# tensor(88.6491, device='cuda:0')
# tensor(77.7679, device='cuda:0')
#
#
# tensor(88.8501, device='cuda:0')
# tensor(78.3818, device='cuda:0')
#
#
# tensor(87.5503, device='cuda:0')
# tensor(77.9082, device='cuda:0')
#
#
# tensor(87.4971, device='cuda:0')
# tensor(77.1552, device='cuda:0')
#
#
# tensor(88.7285, device='cuda:0')
# tensor(79.6492, device='cuda:0')
#
#
# tensor(88.1830, device='cuda:0')
# tensor(78.6383, device='cuda:0')
#
#
# tensor(88.1217, device='cuda:0')
# tensor(77.5292, device='cuda:0')
#
#
# tensor(89.2839, device='cuda:0')
# tensor(79.0646, device='cuda:0')
#
#
# tensor(89.1662, device='cuda:0')
# tensor(78.3704, device='cuda:0')
#
#
# tensor(87.4193, device='cuda:0')
# tensor(76.1814, device='cuda:0')
#
#
# tensor(88.6825, device='cuda:0')
# tensor(77.9048, device='cuda:0')
#
#
# tensor(89.3456, device='cuda:0')
# tensor(78.7531, device='cuda:0')
#
#
# tensor(89.2373, device='cuda:0')
# tensor(78.9413, device='cuda:0')
#
#
# tensor(88.4778, device='cuda:0')
# tensor(78.8082, device='cuda:0')
#
#
# tensor(89.4431, device='cuda:0')
# tensor(79.0632, device='cuda:0')
#
#
# tensor(88.5111, device='cuda:0')
# tensor(77.8446, device='cuda:0')
#
#
# tensor(89.9976, device='cuda:0')
# tensor(78.9191, device='cuda:0')
#
#
# tensor(87.0701, device='cuda:0')
# tensor(77.1878, device='cuda:0')
#
#
# tensor(89.3780, device='cuda:0')
# tensor(79.5513, device='cuda:0')
#
#
# tensor(88.9810, device='cuda:0')
# tensor(78.5180, device='cuda:0')
#
#
# tensor(87.3673, device='cuda:0')
# tensor(78.0972, device='cuda:0')
#
#
# tensor(88.0847, device='cuda:0')
# tensor(77.0101, device='cuda:0')
#
#
# tensor(87.6945, device='cuda:0')
# tensor(77.2465, device='cuda:0')
#
#
# tensor(88.3239, device='cuda:0')
# tensor(77.5648, device='cuda:0')
#
#
# tensor(87.9391, device='cuda:0')
# tensor(77.5853, device='cuda:0')
#
#
# tensor(87.9390, device='cuda:0')
# tensor(77.6108, device='cuda:0')
#
#
# tensor(88.5344, device='cuda:0')
# tensor(78.0162, device='cuda:0')
#
#
# tensor(88.7688, device='cuda:0')
# tensor(78.1042, device='cuda:0')
#
#
# tensor(88.0849, device='cuda:0')
# tensor(77.9544, device='cuda:0')
#
#
# tensor(88.2672, device='cuda:0')
# tensor(77.8995, device='cuda:0')
#
#
# tensor(86.9719, device='cuda:0')
# tensor(77.3793, device='cuda:0')
#
#
# tensor(90.1133, device='cuda:0')
# tensor(79.5458, device='cuda:0')
#
#
# tensor(89.4650, device='cuda:0')
# tensor(78.8154, device='cuda:0')
#
#
# tensor(87.6026, device='cuda:0')
# tensor(77.7021, device='cuda:0')
#
#
# tensor(88.5581, device='cuda:0')
# tensor(78.5757, device='cuda:0')
#
#
# tensor(87.8223, device='cuda:0')
# tensor(76.7377, device='cuda:0')
#
#
# tensor(87.8957, device='cuda:0')
# tensor(77.0037, device='cuda:0')
#
#
# tensor(86.7384, device='cuda:0')
# tensor(76.5930, device='cuda:0')
#
#
# tensor(87.1016, device='cuda:0')
# tensor(77.9545, device='cuda:0')
#
#
# tensor(88.9473, device='cuda:0')
# tensor(77.4477, device='cuda:0')
#
#
# tensor(88.2638, device='cuda:0')
# tensor(77.9178, device='cuda:0')
#
#
# tensor(86.9686, device='cuda:0')
# tensor(76.4751, device='cuda:0')
#
#
# tensor(89.4533, device='cuda:0')
# tensor(79.8297, device='cuda:0')
#
#
# tensor(87.7046, device='cuda:0')
# tensor(77.4668, device='cuda:0')
#
#
# tensor(87.5594, device='cuda:0')
# tensor(77.6876, device='cuda:0')
#
#
# tensor(87.2360, device='cuda:0')
# tensor(77.6138, device='cuda:0')
#
#
# tensor(87.6334, device='cuda:0')
# tensor(77.0875, device='cuda:0')
#
#
# tensor(87.8718, device='cuda:0')
# tensor(77.5612, device='cuda:0')
#
#
# tensor(87.7894, device='cuda:0')
# tensor(77.8603, device='cuda:0')
#
#
# tensor(88.0845, device='cuda:0')
# tensor(77.6363, device='cuda:0')
#
#
# tensor(88.7543, device='cuda:0')
# tensor(77.6568, device='cuda:0')
#
#
# tensor(87.5186, device='cuda:0')
# tensor(77.7838, device='cuda:0')
#
#
# tensor(89.9422, device='cuda:0')
# tensor(79.9201, device='cuda:0')
#
#
# tensor(88.3049, device='cuda:0')
# tensor(79.1767, device='cuda:0')
#
#
# tensor(87.7648, device='cuda:0')
# tensor(77.8113, device='cuda:0')
#
#
# tensor(88.6592, device='cuda:0')
# tensor(78.7914, device='cuda:0')
#
#
# tensor(88.5399, device='cuda:0')
# tensor(78.6218, device='cuda:0')
#
#
# tensor(87.7859, device='cuda:0')
# tensor(77.4520, device='cuda:0')
#
#
# tensor(88.6691, device='cuda:0')
# tensor(79.4866, device='cuda:0')
#
#
# tensor(88.8260, device='cuda:0')
# tensor(78.2479, device='cuda:0')
#
#
# tensor(89.3993, device='cuda:0')
# tensor(78.7113, device='cuda:0')
#
#
# tensor(87.7131, device='cuda:0')
# tensor(77.2852, device='cuda:0')
#
#
# tensor(87.7250, device='cuda:0')
# tensor(77.3199, device='cuda:0')
#
#
# tensor(88.6030, device='cuda:0')
# tensor(77.9214, device='cuda:0')
#
#
# tensor(87.5919, device='cuda:0')
# tensor(78.2142, device='cuda:0')
#
#
# tensor(89.1019, device='cuda:0')
# tensor(79.2166, device='cuda:0')
#
#
# tensor(88.1967, device='cuda:0')
# tensor(78.2700, device='cuda:0')
#
#
# tensor(87.8370, device='cuda:0')
# tensor(77.5229, device='cuda:0')
#
#
# tensor(89.1231, device='cuda:0')
# tensor(78.3016, device='cuda:0')
#
#
# tensor(87.6758, device='cuda:0')
# tensor(76.4678, device='cuda:0')
#
#
# tensor(88.5647, device='cuda:0')
# tensor(78.0514, device='cuda:0')
#
#
# tensor(87.2583, device='cuda:0')
# tensor(76.5114, device='cuda:0')
#
#
# tensor(87.5830, device='cuda:0')
# tensor(77.2734, device='cuda:0')
#
#
# tensor(88.5842, device='cuda:0')
# tensor(78.7841, device='cuda:0')
#
#
# tensor(88.3994, device='cuda:0')
# tensor(78.1491, device='cuda:0')
#
#
# tensor(88.1571, device='cuda:0')
# tensor(77.6779, device='cuda:0')
#
#
# tensor(86.8488, device='cuda:0')
# tensor(77.0366, device='cuda:0')
#
#
# tensor(88.4117, device='cuda:0')
# tensor(78.0039, device='cuda:0')
#
#
# tensor(88.5430, device='cuda:0')
# tensor(78.6802, device='cuda:0')
#
#
# tensor(88.4670, device='cuda:0')
# tensor(78.2070, device='cuda:0')
#
#
# tensor(86.8779, device='cuda:0')
# tensor(76.5727, device='cuda:0')
#
#
# tensor(86.9583, device='cuda:0')
# tensor(75.8371, device='cuda:0')
#
#
# tensor(88.4038, device='cuda:0')
# tensor(78.6417, device='cuda:0')
#
#
# tensor(88.0022, device='cuda:0')
# tensor(77.2625, device='cuda:0')
#
#
# tensor(87.9827, device='cuda:0')
# tensor(77.7025, device='cuda:0')
#
#
# tensor(88.6703, device='cuda:0')
# tensor(79.0646, device='cuda:0')
#
#
# tensor(86.7238, device='cuda:0')
# tensor(77.3137, device='cuda:0')
#
#
# tensor(87.4849, device='cuda:0')
# tensor(77.4888, device='cuda:0')
#
#
# tensor(87.4110, device='cuda:0')
# tensor(77.4832, device='cuda:0')
#
#
# tensor(88.7668, device='cuda:0')
# tensor(77.6821, device='cuda:0')
#
#
# tensor(88.4350, device='cuda:0')
# tensor(78.3388, device='cuda:0')
#
#
# tensor(89.3227, device='cuda:0')
# tensor(78.6860, device='cuda:0')
#
#
# tensor(88.6992, device='cuda:0')
# tensor(77.6769, device='cuda:0')
#
#
# tensor(88.3874, device='cuda:0')
# tensor(78.0141, device='cuda:0')
#
#
# tensor(87.4857, device='cuda:0')
# tensor(77.1423, device='cuda:0')
#
#
# tensor(88.4558, device='cuda:0')
# tensor(77.7762, device='cuda:0')
#
#
# tensor(87.9040, device='cuda:0')
# tensor(78.7280, device='cuda:0')
#
#
# tensor(87.6093, device='cuda:0')
# tensor(77.2818, device='cuda:0')
#
#
# tensor(87.6937, device='cuda:0')
# tensor(76.9389, device='cuda:0')
#
#
# tensor(88.8919, device='cuda:0')
# tensor(78.5922, device='cuda:0')
#
#
# tensor(87.7523, device='cuda:0')
# tensor(77.9992, device='cuda:0')
#
#
# tensor(89.3778, device='cuda:0')
# tensor(79.1737, device='cuda:0')
#
#
# tensor(89.1575, device='cuda:0')
# tensor(79.3416, device='cuda:0')
#
#
# tensor(86.6330, device='cuda:0')
# tensor(77.2096, device='cuda:0')
#
#
# tensor(89.6505, device='cuda:0')
# tensor(79.3942, device='cuda:0')
#
#
# tensor(87.9773, device='cuda:0')
# tensor(77.7274, device='cuda:0')
#
#
# tensor(89.0769, device='cuda:0')
# tensor(78.3288, device='cuda:0')
#
#
# tensor(87.2900, device='cuda:0')
# tensor(76.5895, device='cuda:0')
#
#
# tensor(89.4144, device='cuda:0')
# tensor(80.4394, device='cuda:0')
#
#
# tensor(88.3274, device='cuda:0')
# tensor(78.8293, device='cuda:0')
#
#
# tensor(89.2363, device='cuda:0')
# tensor(78.7805, device='cuda:0')
#
#
# tensor(88.8635, device='cuda:0')
# tensor(78.6575, device='cuda:0')
#
#
# tensor(87.4022, device='cuda:0')
# tensor(77.1409, device='cuda:0')
#
#
# tensor(87.0979, device='cuda:0')
# tensor(77.5266, device='cuda:0')
#
#
# tensor(88.2310, device='cuda:0')
# tensor(78.3897, device='cuda:0')
#
#
# tensor(87.5298, device='cuda:0')
# tensor(77.7245, device='cuda:0')
#
#
# tensor(88.1765, device='cuda:0')
# tensor(77.6534, device='cuda:0')
#
#
# tensor(88.3652, device='cuda:0')
# tensor(78.2721, device='cuda:0')
#
#
# tensor(86.6438, device='cuda:0')
# tensor(76.2496, device='cuda:0')
#
#
# tensor(87.1884, device='cuda:0')
# tensor(77.9605, device='cuda:0')
#
#
# tensor(88.4125, device='cuda:0')
# tensor(78.9838, device='cuda:0')
#
#
# tensor(87.7529, device='cuda:0')
# tensor(77.5448, device='cuda:0')
#
#
# tensor(89.6739, device='cuda:0')
# tensor(79.7764, device='cuda:0')
#
#
# tensor(88.9578, device='cuda:0')
# tensor(79.3752, device='cuda:0')
#
#
# tensor(88.4120, device='cuda:0')
# tensor(77.5360, device='cuda:0')
#
#
# tensor(89.3552, device='cuda:0')
# tensor(78.7368, device='cuda:0')
#
#
# tensor(87.5841, device='cuda:0')
# tensor(77.5187, device='cuda:0')
#
#
# tensor(88.4618, device='cuda:0')
# tensor(77.2036, device='cuda:0')
#
#
# tensor(87.3825, device='cuda:0')
# tensor(77.1142, device='cuda:0')
#
#
# tensor(88.5390, device='cuda:0')
# tensor(77.4752, device='cuda:0')
#
#
# tensor(88.8396, device='cuda:0')
# tensor(78.7528, device='cuda:0')
#
#
# tensor(87.8511, device='cuda:0')
# tensor(77.8721, device='cuda:0')
#
#
# tensor(88.0702, device='cuda:0')
# tensor(78.2753, device='cuda:0')
#
#
# tensor(87.6846, device='cuda:0')
# tensor(77.9428, device='cuda:0')
#
#
# tensor(88.0448, device='cuda:0')
# tensor(77.4386, device='cuda:0')
#
#
# tensor(88.7451, device='cuda:0')
# tensor(77.7138, device='cuda:0')
#
#
# tensor(87.7053, device='cuda:0')
# tensor(79.0269, device='cuda:0')
#
#
# tensor(89.1336, device='cuda:0')
# tensor(78.7577, device='cuda:0')
#
#
# tensor(87.9790, device='cuda:0')
# tensor(77.7979, device='cuda:0')
#
#
# tensor(86.9459, device='cuda:0')
# tensor(76.5718, device='cuda:0')
#
#
# tensor(87.6232, device='cuda:0')
# tensor(76.6404, device='cuda:0')
#
#
# tensor(88.6028, device='cuda:0')
# tensor(78.6329, device='cuda:0')
#
#
# tensor(87.5187, device='cuda:0')
# tensor(77.6130, device='cuda:0')
#
#
# tensor(89.5325, device='cuda:0')
# tensor(79.2092, device='cuda:0')
#
#
# tensor(87.1534, device='cuda:0')
# tensor(77.6241, device='cuda:0')
#
#
# tensor(88.6872, device='cuda:0')
# tensor(78.1785, device='cuda:0')
#
#
# tensor(88.3791, device='cuda:0')
# tensor(78.2454, device='cuda:0')
#
#
# tensor(89.9723, device='cuda:0')
# tensor(79.3611, device='cuda:0')
#
#
# tensor(87.8031, device='cuda:0')
# tensor(77.6855, device='cuda:0')
#
#
# tensor(88.7717, device='cuda:0')
# tensor(78.1413, device='cuda:0')
#
#
# tensor(89.4998, device='cuda:0')
# tensor(79.7080, device='cuda:0')
#
#
# tensor(87.5724, device='cuda:0')
# tensor(76.8111, device='cuda:0')
#
#
# tensor(86.4229, device='cuda:0')
# tensor(77.2934, device='cuda:0')
#
#
# tensor(89.5623, device='cuda:0')
# tensor(78.8150, device='cuda:0')
#
#
# tensor(89.0065, device='cuda:0')
# tensor(78.9371, device='cuda:0')
#
#
# tensor(87.7216, device='cuda:0')
# tensor(77.1739, device='cuda:0')
#
#
# tensor(87.6513, device='cuda:0')
# tensor(77.8539, device='cuda:0')
#
#
# tensor(88.0150, device='cuda:0')
# tensor(77.9996, device='cuda:0')
#
#
# tensor(88.4666, device='cuda:0')
# tensor(78.5168, device='cuda:0')
#
#
# tensor(89.6000, device='cuda:0')
# tensor(79.4201, device='cuda:0')
#
#
# tensor(89.2692, device='cuda:0')
# tensor(78.2625, device='cuda:0')
#
#
# tensor(88.6404, device='cuda:0')
# tensor(78.1378, device='cuda:0')
#
#
# tensor(88.0812, device='cuda:0')
# tensor(77.5649, device='cuda:0')
#
#
# tensor(89.0861, device='cuda:0')
# tensor(77.7067, device='cuda:0')
#
#
# tensor(87.6840, device='cuda:0')
# tensor(77.5058, device='cuda:0')
#
#
# tensor(87.9069, device='cuda:0')
# tensor(78.5511, device='cuda:0')
#
#
# tensor(89.3017, device='cuda:0')
# tensor(79.6586, device='cuda:0')
#
#
# tensor(87.0164, device='cuda:0')
# tensor(76.8853, device='cuda:0')
#
#
# tensor(88.1672, device='cuda:0')
# tensor(78.4528, device='cuda:0')
#
#
# tensor(88.9520, device='cuda:0')
# tensor(78.4934, device='cuda:0')
#
#
# tensor(86.5016, device='cuda:0')
# tensor(77.6629, device='cuda:0')
#
#
# tensor(87.8940, device='cuda:0')
# tensor(77.7476, device='cuda:0')
#
#
# tensor(88.7909, device='cuda:0')
# tensor(79.3373, device='cuda:0')
#
#
# tensor(88.7513, device='cuda:0')
# tensor(78.5913, device='cuda:0')
#
#
# tensor(88.1222, device='cuda:0')
# tensor(77.8533, device='cuda:0')
#
#
# tensor(88.4721, device='cuda:0')
# tensor(77.6014, device='cuda:0')
#
#
# tensor(87.4836, device='cuda:0')
# tensor(76.9874, device='cuda:0')
#
#
# tensor(88.4679, device='cuda:0')
# tensor(77.7585, device='cuda:0')
#
#
# tensor(87.3633, device='cuda:0')
# tensor(76.5285, device='cuda:0')
#
#
# tensor(89.4039, device='cuda:0')
# tensor(79.0657, device='cuda:0')
#
#
# tensor(88.0231, device='cuda:0')
# tensor(77.8364, device='cuda:0')
#
#
# tensor(87.9554, device='cuda:0')
# tensor(78.5160, device='cuda:0')
#
#
# tensor(87.6858, device='cuda:0')
# tensor(77.6295, device='cuda:0')
#
#
# tensor(88.5158, device='cuda:0')
# tensor(78.8282, device='cuda:0')
#
#
# tensor(88.4944, device='cuda:0')
# tensor(78.6765, device='cuda:0')
#
#
# tensor(88.2093, device='cuda:0')
# tensor(78.2871, device='cuda:0')
#
#
# tensor(86.8580, device='cuda:0')
# tensor(77.0784, device='cuda:0')
#
#
# tensor(87.9726, device='cuda:0')
# tensor(78.3791, device='cuda:0')
#
#
# tensor(88.9205, device='cuda:0')
# tensor(78.7421, device='cuda:0')
#
#
# tensor(89.3836, device='cuda:0')
# tensor(78.3703, device='cuda:0')
#
#
# tensor(87.9995, device='cuda:0')
# tensor(77.1967, device='cuda:0')
#
#
# tensor(88.5313, device='cuda:0')
# tensor(79.0823, device='cuda:0')
#
#
# tensor(87.6623, device='cuda:0')
# tensor(77.0963, device='cuda:0')
#
#
# tensor(87.3210, device='cuda:0')
# tensor(76.7279, device='cuda:0')
#
#
# tensor(87.5343, device='cuda:0')
# tensor(78.4017, device='cuda:0')
#
#
# tensor(88.4850, device='cuda:0')
# tensor(78.4599, device='cuda:0')
#
#
# tensor(87.0477, device='cuda:0')
# tensor(77.7263, device='cuda:0')
#
#
# tensor(88.4604, device='cuda:0')
# tensor(78.7543, device='cuda:0')
#
#
# tensor(89.0796, device='cuda:0')
# tensor(78.4637, device='cuda:0')
#
#
# tensor(88.4602, device='cuda:0')
# tensor(78.2810, device='cuda:0')
#
#
# tensor(89.0951, device='cuda:0')
# tensor(79.6560, device='cuda:0')
#
#
# tensor(88.7417, device='cuda:0')
# tensor(77.9303, device='cuda:0')
#
#
# tensor(88.4985, device='cuda:0')
# tensor(78.7167, device='cuda:0')
#
#
# tensor(88.2184, device='cuda:0')
# tensor(77.7918, device='cuda:0')
#
#
# tensor(86.5350, device='cuda:0')
# tensor(76.5462, device='cuda:0')
#
#
# tensor(88.0090, device='cuda:0')
# tensor(78.0670, device='cuda:0')
#
#
# tensor(86.9173, device='cuda:0')
# tensor(77.2229, device='cuda:0')
#
#
# tensor(88.3835, device='cuda:0')
# tensor(78.7059, device='cuda:0')
#
#
# tensor(88.7770, device='cuda:0')
# tensor(78.1003, device='cuda:0')
#
#
# tensor(88.6876, device='cuda:0')
# tensor(78.2487, device='cuda:0')
#
#
# tensor(89.0903, device='cuda:0')
# tensor(78.7384, device='cuda:0')
#
#
# tensor(87.6913, device='cuda:0')
# tensor(78.4308, device='cuda:0')
#
#
# tensor(88.9170, device='cuda:0')
# tensor(78.6097, device='cuda:0')
#
#
# tensor(88.5046, device='cuda:0')
# tensor(78.1250, device='cuda:0')
#
#
# tensor(88.0296, device='cuda:0')
# tensor(77.1451, device='cuda:0')
#
#
# tensor(89.6317, device='cuda:0')
# tensor(78.9185, device='cuda:0')
#
#
# tensor(88.6056, device='cuda:0')
# tensor(77.8800, device='cuda:0')
#
#
# tensor(88.3820, device='cuda:0')
# tensor(78.4777, device='cuda:0')
#
#
# tensor(87.6510, device='cuda:0')
# tensor(77.8320, device='cuda:0')
#
#
# tensor(88.2752, device='cuda:0')
# tensor(77.7875, device='cuda:0')
#
#
# tensor(88.1786, device='cuda:0')
# tensor(77.6740, device='cuda:0')
#
#
# tensor(89.3642, device='cuda:0')
# tensor(79.0294, device='cuda:0')
#
#
# tensor(88.2076, device='cuda:0')
# tensor(78.5882, device='cuda:0')
#
#
# tensor(88.1367, device='cuda:0')
# tensor(78.4157, device='cuda:0')
#
#
# tensor(89.4791, device='cuda:0')
# tensor(79.4659, device='cuda:0')
#
#
# tensor(88.6981, device='cuda:0')
# tensor(78.6543, device='cuda:0')
#
#
# tensor(88.8735, device='cuda:0')
# tensor(78.3602, device='cuda:0')
#
#
# tensor(87.9721, device='cuda:0')
# tensor(78.3322, device='cuda:0')
#
#
# tensor(87.0821, device='cuda:0')
# tensor(77.2212, device='cuda:0')
#
#
# tensor(88.1742, device='cuda:0')
# tensor(78.0880, device='cuda:0')
#
#
# tensor(87.2530, device='cuda:0')
# tensor(77.4147, device='cuda:0')
#
#
# tensor(87.3454, device='cuda:0')
# tensor(77.6992, device='cuda:0')
#
#
# tensor(87.6599, device='cuda:0')
# tensor(77.2520, device='cuda:0')
#
#
# tensor(88.1815, device='cuda:0')
# tensor(77.6960, device='cuda:0')
#
#
# tensor(87.1990, device='cuda:0')
# tensor(77.3014, device='cuda:0')
#
#
# tensor(88.8284, device='cuda:0')
# tensor(77.9041, device='cuda:0')
#
#
# tensor(86.9756, device='cuda:0')
# tensor(76.9325, device='cuda:0')
#
#
# tensor(89.0599, device='cuda:0')
# tensor(78.5011, device='cuda:0')
#
#
# tensor(88.3249, device='cuda:0')
# tensor(78.3374, device='cuda:0')
#
#
# tensor(89.0029, device='cuda:0')
# tensor(77.7712, device='cuda:0')
#
#
# tensor(87.4645, device='cuda:0')
# tensor(76.8556, device='cuda:0')
#
#
# tensor(88.6735, device='cuda:0')
# tensor(77.8785, device='cuda:0')
#
#
# tensor(89.0008, device='cuda:0')
# tensor(78.9909, device='cuda:0')
#
#
# tensor(88.5830, device='cuda:0')
# tensor(78.2065, device='cuda:0')
#
#
# tensor(87.4790, device='cuda:0')
# tensor(77.7449, device='cuda:0')
#
#
# tensor(90.1057, device='cuda:0')
# tensor(79.8398, device='cuda:0')
#
#
# tensor(87.6163, device='cuda:0')
# tensor(77.1923, device='cuda:0')
#
#
# tensor(87.1570, device='cuda:0')
# tensor(77.0497, device='cuda:0')
#
#
# tensor(89.0157, device='cuda:0')
# tensor(77.9190, device='cuda:0')
#
#
# tensor(87.6533, device='cuda:0')
# tensor(76.4466, device='cuda:0')
#
#
# tensor(89.1098, device='cuda:0')
# tensor(78.8883, device='cuda:0')
#
#
# tensor(88.4856, device='cuda:0')
# tensor(78.1209, device='cuda:0')
#
#
# tensor(87.7253, device='cuda:0')
# tensor(78.1509, device='cuda:0')
#
#
# tensor(87.5342, device='cuda:0')
# tensor(77.4408, device='cuda:0')
#
#
# tensor(87.4987, device='cuda:0')
# tensor(78.0066, device='cuda:0')
#
#
# tensor(87.4670, device='cuda:0')
# tensor(78.3810, device='cuda:0')
#
#
# tensor(90.8054, device='cuda:0')
# tensor(79.5383, device='cuda:0')
#
#
# tensor(88.1103, device='cuda:0')
# tensor(79.1991, device='cuda:0')
#
#
# tensor(86.8323, device='cuda:0')
# tensor(77.1291, device='cuda:0')
#
#
# tensor(86.6464, device='cuda:0')
# tensor(76.8528, device='cuda:0')
#
#
# tensor(85.7833, device='cuda:0')
# tensor(76.0866, device='cuda:0')
#
#
# tensor(89.0761, device='cuda:0')
# tensor(79.3324, device='cuda:0')
#
#
# tensor(87.0860, device='cuda:0')
# tensor(77.2594, device='cuda:0')
#
#
# tensor(88.6888, device='cuda:0')
# tensor(78.8620, device='cuda:0')
#
#
# tensor(89.0363, device='cuda:0')
# tensor(78.7984, device='cuda:0')
#
#
# tensor(87.4076, device='cuda:0')
# tensor(77.3748, device='cuda:0')
#
#
# tensor(89.8087, device='cuda:0')
# tensor(79.7256, device='cuda:0')
#
#
# tensor(88.3409, device='cuda:0')
# tensor(78.3464, device='cuda:0')
#
#
# tensor(88.5421, device='cuda:0')
# tensor(77.6355, device='cuda:0')
#
#
# tensor(89.4752, device='cuda:0')
# tensor(78.6392, device='cuda:0')
#
#
# tensor(87.4825, device='cuda:0')
# tensor(78.2896, device='cuda:0')
#
#
# tensor(88.0746, device='cuda:0')
# tensor(78.3979, device='cuda:0')
#
#
# tensor(88.0178, device='cuda:0')
# tensor(78.3053, device='cuda:0')
#
#
# tensor(87.8432, device='cuda:0')
# tensor(77.5706, device='cuda:0')
#
#
# tensor(87.9929, device='cuda:0')
# tensor(77.8784, device='cuda:0')
#
#
# tensor(88.5319, device='cuda:0')
# tensor(77.7737, device='cuda:0')
#
#
# tensor(87.4750, device='cuda:0')
# tensor(77.8598, device='cuda:0')
#
#
# tensor(88.1848, device='cuda:0')
# tensor(78.2585, device='cuda:0')
#
#
# tensor(88.5289, device='cuda:0')
# tensor(77.5915, device='cuda:0')
#
#
# tensor(88.2597, device='cuda:0')
# tensor(78.4760, device='cuda:0')
#
#
# tensor(89.7609, device='cuda:0')
# tensor(78.0954, device='cuda:0')
#
#
# tensor(89.0840, device='cuda:0')
# tensor(79.5172, device='cuda:0')
#
#
# tensor(88.1572, device='cuda:0')
# tensor(78.2300, device='cuda:0')
#
#
# tensor(88.0913, device='cuda:0')
# tensor(77.9814, device='cuda:0')
#
#
# tensor(87.6438, device='cuda:0')
# tensor(77.4638, device='cuda:0')
#
#
# tensor(87.4018, device='cuda:0')
# tensor(77.5142, device='cuda:0')
#
#
# tensor(87.9199, device='cuda:0')
# tensor(77.0034, device='cuda:0')
#
#
# tensor(89.1603, device='cuda:0')
# tensor(78.1163, device='cuda:0')
#
#
# tensor(86.9337, device='cuda:0')
# tensor(77.4773, device='cuda:0')
#
#
# tensor(88.1060, device='cuda:0')
# tensor(77.8223, device='cuda:0')
#
#
# tensor(87.3401, device='cuda:0')
# tensor(78.1139, device='cuda:0')
#
#
# tensor(87.9882, device='cuda:0')
# tensor(77.6706, device='cuda:0')
#
#
# tensor(87.3066, device='cuda:0')
# tensor(76.9611, device='cuda:0')
#
#
# tensor(88.6369, device='cuda:0')
# tensor(78.0173, device='cuda:0')
#
#
# 500

# %%
print(calculate_all_norms(reconstructed_matrix_svd, fixed_matrix))
print(calculate_all_norms(reconstructed_svd_full, fixed_matrix))

# print(calculate_all_norms(ysvd, true_res))
# print(calculate_all_norms(ymonarch, true_res))
# Out:
# {'fro': tensor(0., device='cuda:0'), 'nuc': tensor(0., device='cuda:0'), 'spectral': tensor(0., device='cuda:0')}
# {'fro': tensor(35.6478, device='cuda:0'), 'nuc': tensor(880.5148, device='cuda:0'), 'spectral': tensor(4.7447, device='cuda:0')}
